# %%
#Read Data

import os
import csv
import pprint

# Reading 'menu_data.csv' and creating a list of lists menu[].
menu = []


with open('RESOURCES/menu_data.csv','r') as csvfile:
    menu_data = csv.reader(csvfile)
    next(menu_data)  
 
    for row in menu_data:
        menu.append(row)


# Creating a list for each colum of menu_data for further use       

item = []
categories = []
description = []
price = []
cost = []

for i in menu:
        item.append(i[0])
        description.append(i[1])
        description.append(i[2])
        price.append(i[3])
        cost.append(i[4])
        
# Reading 'sales_data.csv'and creating a list os lists Sales[]
sales = []

with open('RESOURCES/sales_data.csv','r') as csvfile:
    sales_data = csv.reader(csvfile)
    next(sales_data)  
 
    for row in sales_data:
        sales.append(row)

# %%
import pandas as pd

menu = pd.read_csv('RESOURCES/menu_data.csv')
menu.head()
menu.tail(10)
# Out:
#                                               item  category  \
# 22                     burnt garlic tonkotsu ramen    entree
# 23  vegetarian curry + king trumpet mushroom ramen    entree
# 24                            truffle butter ramen    entree
# 25                                       green tea    drinks
# 26                                            coke    drinks
# 27                          black sesame ice cream  desserts
# 28                                matcha ice cream  desserts
# 29                           mango mochi ice cream  desserts
# 30                      strawberry mochi ice cream  desserts
# 31                       black sesame creme brulee  desserts
#
#                                           description  price  cost
# 22  rich, shoyi and burnt garlic seasoned niman ra...   14.0     6
# 23  house curry blend + vegan dashi; fried king tr...   13.0     7
# 24  rich, shoyu seasoned niman ranch prok bone sto...   14.0     7
# ...

# %%
sales = pd.read_csv('RESOURCES/sales_data.csv')
sales.head(30)
# Out:
#     Line_Item_ID        Date  Credit_Card_Number  Quantity  \
# 0              1  01-01-2017    7437926611570799         1
# 1              2  01-01-2017    7437926611570799         1
# 2              3  01-01-2017    8421920068932819         3
# 3              4  01-01-2017    8421920068932819         3
# 4              5  01-01-2017    4787310681569648         1
# 5              6  01-01-2017    4787310681569648         1
# 6              7  01-01-2017    8252818705821725         1
# 7              8  01-01-2017    8252818705821725         1
# 8              9  01-01-2017    3119034881407323         1
# 9             10  01-01-2017    3119034881407323         1
# 10            11  01-01-2017    5185620052605569         1
# 11            12  01-01-2017    5185620052605569         1
# 12            13  01-01-2017    1625774198697856         1
# 13            14  01-01-2017    1625774198697856         1
# 14            15  01-01-2017     505248472056578         1
# ...
